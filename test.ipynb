# %%
import torch
import torch.nn as nn

# Define your neural network
class MyNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(MyNetwork, self).__init__()
        self.fc = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        return self.fc(x)

# Assuming U_inner is generated by the network
input_dim = 2  # Assuming input features are concatenated from x_f and t_f
output_dim = 1  # Assuming U_inner is 1D

# Create your neural network and set requires_grad=True for its parameters
U = MyNetwork(input_dim, output_dim)
for param in U.parameters():
    param.requires_grad = True

U.train()

# Assuming x_f and t_f are tensors
x_f = torch.randn(10, 1)  # Replace with your actual input
x_f.requires_grad = True
t_f = torch.randn(10,1)  # Replace with your actual input
t_f.requires_grad = True
# Concatenate x_f and t_f
input_data = torch.cat((x_f, t_f), 1)

# Pass the input through the neural network to generate U_inner
U_inner = U(input_data)

# Compute the gradient
grad_U = torch.autograd.grad(U_inner, t_f, torch.ones_like(U_inner), create_graph=True)
# U_scalar = U_inner.sum()
# grad_U = torch.autograd.grad(U_scalar, t_f[1], create_graph=True)
# Now grad_U is the gradient of U_inner with respect to t_f
# Out:
# MyNetwork(
#   (fc): Linear(in_features=2, out_features=1, bias=True)
# )

# %%
import torch
import torch.nn as nn
from torch.optim import LBFGS

# Define a simple neural network
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(2, 2)
        self.fc2 = nn.Linear(2, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Define a toy dataset and corresponding targets
data = torch.randn(100, 2)
targets = torch.randn(100, 1)

# Define the custom closure function
def closure():
    #print('Inside closure')
    optimizer.zero_grad()
    output = net(data)
    loss = criterion(output, targets)
    loss.backward()
    return loss

# Initialize the network, loss criterion, and optimizer
net = Net()
criterion = nn.MSELoss()
optimizer = LBFGS(net.parameters(), lr=0.01)

# Training loop
for i in range(100):
    optimizer.step(closure)
    
# After the loop, your network parameters are optimized.
# Out:
# Inside loop
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# tensor(2.0040, grad_fn=<MseLossBackward0>)
# Outside closure
# Inside loop
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# tensor(1.4512, grad_fn=<MseLossBackward0>)
# Outside closure
# Inside loop
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# Inside closure
# ...
